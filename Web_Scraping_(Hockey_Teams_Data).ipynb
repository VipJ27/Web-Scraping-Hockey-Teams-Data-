# %% [markdown]
# <a href="https://colab.research.google.com/github/VipJ27/Web-Scraping-Hockey-Teams-Data-/blob/main/Web_Scraping_(Hockey_Teams_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.scrapethissite.com/pages/forms/"

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
table = soup.find('table', class_ = 'table')

print(table)
# Out:
# <table class="table">
# <tr>
# <th>
#                             Team Name
#                         </th>
# <th>
#                             Year
#                         </th>
# <th>
#                             Wins
#                         </th>
# <th>
#                             Losses
#                         </th>
# <th>
#                             OT Losses
#                         </th>
# <th>
#                             Win %
#                         </th>
# <th>
#                             Goals For (GF)
#                         </th>
# <th>
#                             Goals Against (GA)
#                         </th>
# <th>
#                             + / -
#                         </th>
# </tr>
# <tr class="team">
# <td class="name">
#                             Boston Bruins
#                         </td>
# <td class="year">
#                             1990
#                         </td>
# <td class="wins">
#                             44
# ...

# %%
titles = table.find_all('th')

print(titles)
# Out:
# [<th>
#                             Team Name
#                         </th>, <th>
#                             Year
#                         </th>, <th>
#                             Wins
#                         </th>, <th>
#                             Losses
#                         </th>, <th>
#                             OT Losses
#                         </th>, <th>
#                             Win %
#                         </th>, <th>
#                             Goals For (GF)
#                         </th>, <th>
#                             Goals Against (GA)
#                         </th>, <th>
#                             + / -
#                         </th>]

# %%
headings = [title.text.strip() for title in titles]

print(headings)
# Out:
# ['Team Name', 'Year', 'Wins', 'Losses', 'OT Losses', 'Win %', 'Goals For (GF)', 'Goals Against (GA)', '+ / -']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = headings)

df
# Out:
# Empty DataFrame
# Columns: [Team Name, Year, Wins, Losses, OT Losses, Win %, Goals For (GF), Goals Against (GA), + / -]
# Index: []

# %%
column_data = table.find_all('tr')[1:]

print(column_data)
# Out:
# [<tr class="team">
# <td class="name">
#                             Boston Bruins
#                         </td>
# <td class="year">
#                             1990
#                         </td>
# <td class="wins">
#                             44
#                         </td>
# <td class="losses">
#                             24
#                         </td>
# <td class="ot-losses">
# </td>
# <td class="pct text-success">
#                             0.55
#                         </td>
# <td class="gf">
#                             299
#                         </td>
# <td class="ga">
#                             264
#                         </td>
# <td class="diff text-success">
#                             35
#                         </td>
# </tr>, <tr class="team">
# <td class="name">
#                             Buffalo Sabres
#                         </td>
# <td class="year">
#                             1990
#                         </td>
# ...

# %%
for row in column_data:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                 Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0           Boston Bruins  1990   44     24             0.55            299
# 1          Buffalo Sabres  1990   31     30            0.388            292
# 2          Calgary Flames  1990   46     26            0.575            344
# 3      Chicago Blackhawks  1990   49     23            0.613            284
# 4       Detroit Red Wings  1990   34     38            0.425            273
# 5         Edmonton Oilers  1990   37     37            0.463            272
# 6        Hartford Whalers  1990   31     38            0.388            238
# 7       Los Angeles Kings  1990   46     24            0.575            340
# 8   Minnesota North Stars  1990   27     39            0.338            256
# 9      Montreal Canadiens  1990   39     30            0.487            273
# 10      New Jersey Devils  1990   32     33              0.4            272
# ...

# %%
df.to_csv(r'C:\Users\jaisw\OneDrive\Documents\Datasets\HockeyData.csv', index = False)
